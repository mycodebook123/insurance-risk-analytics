# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# Task 3: A/B Hypothesis Testing\n", "## AlphaCare Insurance Solutions\n", "Testing 4 null hypotheses about risk drivers across provinces, zip codes, and gender."]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import numpy as np\n",
    "from scipy import stats\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import sys\n",
    "sys.path.append('..')\n",
    "from src.data_loader import load_data, add_derived_metrics\n",
    "from src.hypothesis_tests import test_provinces, test_zipcodes_risk, test_zipcodes_margin, test_gender\n",
    "import warnings\n",
    "warnings.filterwarnings('ignore')\n",
    "print('Libraries loaded.')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df = load_data()\n",
    "df = add_derived_metrics(df)\n",
    "print(f'Dataset loaded: {df.shape}')"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## H1: No risk differences across provinces"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "h1_result = test_provinces(df)\n",
    "print(h1_result)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## H2: No risk differences between zip codes"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "h2_result = test_zipcodes_risk(df)\n",
    "print(h2_result)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## H3: No margin difference between zip codes"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "h3_result = test_zipcodes_margin(df)\n",
    "print(h3_result)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## H4: No risk difference between Women and Men"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "h4_result = test_gender(df)\n",
    "print(h4_result)"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["## Results Summary"]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "results = pd.DataFrame([\n",
    "    h1_result, h2_result, h3_result, h4_result\n",
    "])\n",
    "print('\\n── Hypothesis Testing Results ──')\n",
    "print(results.to_string(index=False))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.13.2"}
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
